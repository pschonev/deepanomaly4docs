# %%
import pandas as pd

files = ["/home/philipp/projects/dad4td/reports/clustering/0001_cluster_roberta_lowered.tsv"]
df = pd.concat([pd.read_csv(filename, sep="\t") for filename in files]).reset_index(drop=True)

df_mean = df.groupby("hash").mean()
df_mean = df_mean.sort_values("f1_macro")

score_cols = ['completeness',
              'f1_macro',
              'homogeneity',
              'in_f1',
              'out_f1',
              'out_prec',
              'out_rec',
              'v_measure',
             'cluster_n']
data_cols = ['Unnamed: 0',
             'contamination',
             'data_frac',
             'seed']
param_cols = [x for x in list(df.columns) if x not in score_cols]
param_cols = [x for x in param_cols if x not in data_cols]
cols = score_cols + param_cols
df
# Out:
#      Unnamed: 0  cluster_n  completeness  contamination  data_frac  f1_macro  \
# 0             0        5.0      0.220295            0.1       0.15  0.512800
# 1             1        5.0      0.188900            0.1       0.15  0.530056
# 2             2        6.0      0.188700            0.1       0.15  0.519128
# 3             3        6.0      0.188700            0.1       0.15  0.524304
# 4             4        6.0      0.187913            0.1       0.15  0.529481
# ..          ...        ...           ...            ...        ...       ...
# 175         175        7.0      0.245605            0.1       0.15  0.524880
# 176         176        5.0      0.508484            0.1       0.15  0.546162
# 177         177        8.0      0.236261            0.1       0.15  0.512800
# 178         178        7.0      0.320243            0.1       0.15  0.522004
# 179         179        8.0      0.249262            0.1       0.15  0.512800
#
#                   hash  homogeneity     in_f1  min_cluster_sizes_  \
# 0    10|1.0|cosine|120     0.234967  0.906974               120.0
# 1     10|0.5|cosine|30     0.237452  0.910269                30.0
# 2     10|1.0|cosine|60     0.237475  0.908182                60.0
# 3     10|1.0|cosine|90     0.237475  0.909171                90.0
# 4     10|0.3|cosine|30     0.237569  0.910159                30.0
# ..                 ...          ...       ...                 ...
# 175  10|0.5|cosine|120     0.880814  0.909281               120.0
# 176   10|0.5|cosine|30     0.886807  0.913344                30.0
# 177   10|0.5|cosine|60     0.887431  0.906974                60.0
# 178    3|1.0|cosine|90     0.930601  0.908731                90.0
# 179   10|0.5|cosine|90     0.942439  0.906974                90.0
#
#      mix_ratios_  n_comps_    out_f1  out_prec   out_rec  seed       time  \
# 0            1.0      10.0  0.118626  0.113208  0.124590  44.0  22.364776
# 1            0.5      10.0  0.149844  0.142999  0.157377  44.0  16.006099
# 2            1.0      10.0  0.130073  0.124131  0.136612  44.0  21.886440
# 3            1.0      10.0  0.139438  0.133069  0.146448  44.0  22.334238
# 4            0.3      10.0  0.148803  0.142006  0.156284  44.0  13.408320
# ..           ...       ...       ...       ...       ...   ...        ...
# 175          0.5      10.0  0.140479  0.134062  0.147541  43.0  16.651768
# 176          0.5      10.0  0.178980  0.170804  0.187978  43.0  15.835963
# 177          0.5      10.0  0.118626  0.113208  0.124590  43.0  16.227750
# 178          1.0       3.0  0.135276  0.129096  0.142077  42.0  18.464438
# 179          0.5      10.0  0.118626  0.113208  0.124590  43.0  16.404219
#
#     umap_metrics_  v_measure
# 0          cosine   0.227395
# 1          cosine   0.210411
# 2          cosine   0.210297
# 3          cosine   0.210297
# 4          cosine   0.209843
# ..            ...        ...
# 175        cosine   0.384107
# 176        cosine   0.646356
# 177        cosine   0.373172
# 178        cosine   0.476508
# 179        cosine   0.394251
#
# [180 rows x 19 columns]

# %%
# best f1 macro
df_mean = df.groupby("hash")[score_cols].mean()
df_mean = df_mean.reset_index()
df_mean = df_mean.sort_values(by="homogeneity", ascending=False).reset_index(drop=True)
df_mean.head(20)
# Out:
#                  hash  completeness  f1_macro  homogeneity     in_f1  \
# 0     3|1.0|cosine|90      0.317852  0.515101     0.831944  0.907414
# 1    10|0.5|cosine|90      0.318275  0.520086     0.829217  0.908365
# 2   10|0.5|cosine|120      0.397926  0.525838     0.808590  0.909464
# 3     3|0.4|cosine|30      0.190927  0.570704     0.787374  0.918030
# 4     3|1.0|cosine|30      0.199253  0.561885     0.781266  0.916346
# 5     3|0.3|cosine|30      0.334736  0.555941     0.780886  0.915211
# 6    3|0.5|cosine|120      0.292666  0.535233     0.780663  0.911258
# 7     5|0.4|cosine|30      0.351266  0.546162     0.780658  0.913344
# 8     5|0.4|cosine|90      0.352426  0.515293     0.780630  0.907450
# 9     3|0.5|cosine|30      0.430024  0.548080     0.780591  0.913710
# 10   5|0.4|cosine|120      0.389721  0.527564     0.780537  0.909793
# 11   3|0.3|cosine|120      0.392323  0.534850     0.780476  0.911184
# 12    5|0.5|cosine|30      0.336142  0.550189     0.780235  0.914113
# 13    5|0.6|cosine|30      0.277686  0.525263     0.780177  0.909354
# 14    3|0.6|cosine|30      0.352228  0.565528     0.780159  0.917042
# 15    3|0.6|cosine|60      0.381962  0.532741     0.780012  0.910782
# 16   10|0.6|cosine|30      0.351351  0.541944     0.779927  0.912539
# 17   3|0.6|cosine|120      0.481780  0.532933     0.779917  0.910818
# 18   10|0.6|cosine|90      0.430151  0.518744     0.779851  0.908109
# 19  10|0.6|cosine|120      0.389310  0.524688     0.779813  0.909244
#
#       out_f1  out_prec   out_rec  v_measure  cluster_n
# 0   0.122789  0.117180  0.128962   0.451725   6.666667
# 1   0.131807  0.125786  0.138434   0.451533   6.666667
# 2   0.142213  0.135717  0.149362   0.519745   5.000000
# 3   0.223378  0.213174  0.234608   0.306650  10.000000
# 4   0.207423  0.197948  0.217851   0.315177   9.666667
# 5   0.196670  0.187686  0.206557   0.450181   7.666667
# 6   0.159209  0.151936  0.167213   0.407229   6.666667
# 7   0.178980  0.170804  0.187978   0.474182   6.333333
# 8   0.123136  0.117511  0.129326   0.475641   6.000000
# 9   0.182449  0.174115  0.191621   0.554539   5.000000
# 10  0.145335  0.138696  0.152641   0.506959   5.000000
# 11  0.158515  0.151274  0.166485   0.509152   5.000000
# 12  0.186264  0.177756  0.195628   0.452187   7.666667
# 13  0.141172  0.134724  0.148270   0.395561   8.000000
# 14  0.214013  0.204237  0.224772   0.475468   6.000000
# 15  0.154700  0.147633  0.162477   0.508787   5.666667
# 16  0.171349  0.163522  0.179964   0.474118   6.333333
# 17  0.155047  0.147964  0.162842   0.595601   5.000000
# 18  0.129379  0.123469  0.135883   0.554458   5.000000
# 19  0.140132  0.133731  0.147177   0.506421   5.000000

# %%
#worst f1 macro
df_mean = df.groupby("hash")[score_cols].mean()
df_mean = df_mean.reset_index()
df_mean = df_mean.sort_values(by="f1_macro", ascending=True).reset_index(drop=True)
df_mean.head(20)
# Out:
#                  hash  completeness  f1_macro  homogeneity     in_f1  \
# 0     5|1.0|cosine|60      0.184487  0.506473     0.603059  0.905766
# 1    10|1.0|cosine|90      0.196960  0.514526     0.423211  0.907304
# 2     5|1.0|cosine|90      0.229598  0.514909     0.602844  0.907377
# 3     3|1.0|cosine|90      0.317852  0.515101     0.831944  0.907414
# 4     5|0.4|cosine|90      0.352426  0.515293     0.780630  0.907450
# 5    10|0.4|cosine|60      0.262193  0.516252     0.776803  0.907633
# 6     5|0.3|cosine|90      0.350904  0.516799     0.777415  0.908071
# 7     3|0.3|cosine|90      0.351894  0.516827     0.778684  0.907743
# 8    10|0.6|cosine|60      0.325594  0.518169     0.610645  0.907999
# 9    10|0.6|cosine|90      0.430151  0.518744     0.779851  0.908109
# 10    3|0.5|cosine|60      0.274112  0.519703     0.600188  0.908292
# 11   10|0.5|cosine|90      0.318275  0.520086     0.829217  0.908365
# 12   3|1.0|cosine|120      0.302424  0.520470     0.779154  0.908439
# 13   10|1.0|cosine|60      0.197003  0.521045     0.423212  0.908548
# 14    3|0.6|cosine|90      0.350348  0.521428     0.600063  0.908622
# 15   5|0.6|cosine|120      0.341259  0.521812     0.598463  0.908695
# 16   10|0.5|cosine|60      0.257362  0.522771     0.643639  0.908878
# 17    5|0.4|cosine|60      0.275229  0.523154     0.603023  0.908951
# 18    5|0.3|cosine|60      0.349577  0.523537     0.597988  0.909024
# 19  10|0.4|cosine|120      0.388318  0.524688     0.776485  0.909244
#
#       out_f1  out_prec   out_rec  v_measure  cluster_n
# 0   0.107180  0.102284  0.112568   0.266141   8.000000
# 1   0.121748  0.116187  0.127869   0.252022   6.666667
# 2   0.122442  0.116849  0.128597   0.321404   7.000000
# 3   0.122789  0.117180  0.128962   0.451725   6.666667
# 4   0.123136  0.117511  0.129326   0.475641   6.000000
# 5   0.124870  0.119166  0.131148   0.378064   7.666667
# 6   0.125527  0.120067  0.131512   0.473553   6.000000
# 7   0.125911  0.120159  0.132240   0.473321   6.333333
# 8   0.128339  0.122476  0.134791   0.423869   5.333333
# 9   0.129379  0.123469  0.135883   0.554458   5.000000
# 10  0.131113  0.125124  0.137705   0.361191   6.333333
# 11  0.131807  0.125786  0.138434   0.451533   6.666667
# 12  0.132501  0.126448  0.139162   0.421786   6.333333
# 13  0.133541  0.127441  0.140255   0.252076   6.333333
# 14  0.134235  0.128103  0.140984   0.440074   5.000000
# 15  0.134929  0.128765  0.141712   0.424560   5.000000
# 16  0.136663  0.130420  0.143534   0.359707   6.666667
# 17  0.137357  0.131082  0.144262   0.364568   6.000000
# 18  0.138051  0.131744  0.144991   0.438911   5.000000
# 19  0.140132  0.133731  0.147177   0.504925   5.000000

# %%
df_mean = df.groupby("mix_ratios_")[score_cols].mean()
df_mean = df_mean.reset_index()
df_mean = df_mean.sort_values(by="f1_macro", ascending=False).reset_index(drop=True)
df_mean.head(20)
# Out:
#    mix_ratios_  completeness  f1_macro  homogeneity     in_f1    out_f1  \
# 0          0.3      0.316658  0.534488     0.661208  0.911158  0.157818
# 1          0.4      0.325037  0.532472     0.731885  0.910745  0.154200
# 2          0.5      0.317508  0.531116     0.690314  0.910506  0.151726
# 3          0.6      0.361917  0.529977     0.735511  0.910254  0.149699
# 4          1.0      0.290627  0.528123     0.679867  0.909900  0.146346
#
#    out_prec   out_rec  v_measure  cluster_n
# 0  0.150657  0.165695   0.413990   6.194444
# 1  0.147173  0.161931   0.436875   6.388889
# 2  0.144823  0.159320   0.422259   6.138889
# 3  0.142861  0.157225   0.475703   5.750000
# 4  0.139661  0.153704   0.391293   6.666667

# %%
df_mean = df.groupby("n_comps_")[score_cols].mean()
df_mean = df_mean.reset_index()
df_mean = df_mean.sort_values(by="f1_macro", ascending=False).reset_index(drop=True)
df_mean.head(20)
# Out:
#    n_comps_  completeness  f1_macro  homogeneity     in_f1    out_f1  \
# 0       3.0      0.314249  0.536721     0.727410  0.911550  0.161892
# 1       5.0      0.330370  0.529694     0.709161  0.910237  0.149150
# 2      10.0      0.322430  0.527291     0.662699  0.909750  0.144832
#
#    out_prec   out_rec  v_measure  cluster_n
# 0  0.154507  0.170018   0.424099   6.683333
# 1  0.142368  0.156612   0.438294   6.066667
# 2  0.138231  0.152095   0.421679   5.933333

# %%
df_mean = df.groupby("min_cluster_sizes_")[score_cols].mean()
df_mean = df_mean.reset_index()
df_mean = df_mean.sort_values(by="f1_macro", ascending=False).reset_index(drop=True)
df_mean.head(20)
# Out:
#    min_cluster_sizes_  completeness  f1_macro  homogeneity     in_f1  \
# 0                30.0      0.331427  0.548322     0.746518  0.913757
# 1               120.0      0.382781  0.528676     0.723454  0.910005
# 2                60.0      0.281100  0.524547     0.651337  0.909217
# 3                90.0      0.294091  0.523395     0.677720  0.909071
#
#      out_f1  out_prec   out_rec  v_measure  cluster_n
# 0  0.182888  0.174534  0.192083   0.446114   6.711111
# 1  0.147347  0.140616  0.154754   0.488832   5.111111
# 2  0.139877  0.133488  0.146910   0.378463   6.600000
# 3  0.137719  0.131503  0.144554   0.398687   6.488889

# %%
df_mean = df.groupby("cluster_n")[score_cols].mean()
df_mean["count_cluster_n"] = df.groupby("cluster_n")[score_cols].size()
df_mean = df_mean.sort_values(by="f1_macro", ascending=False).reset_index(drop=True)
df_mean.head(20)
# Out:
#    completeness  f1_macro  homogeneity     in_f1    out_f1  out_prec  \
# 0      0.195349  0.571184     0.762773  0.918122  0.224246  0.214002
# 1      0.169867  0.540554     0.775457  0.912273  0.168835  0.161122
# 2      0.147250  0.536815     0.783333  0.911560  0.162071  0.154667
# 3      0.140211  0.534371     0.751103  0.911093  0.157648  0.150447
# 4      0.398890  0.531667     0.695437  0.910610  0.152724  0.145777
# 5      0.202640  0.528253     0.343249  0.909975  0.146532  0.139920
# 6      0.198412  0.528054     0.738067  0.909887  0.146221  0.139542
# 7      0.477663  0.526277     0.776695  0.909547  0.143006  0.136473
# 8      0.218791  0.522680     0.708254  0.908861  0.136500  0.130265
# 9      0.155607  0.513567     0.780321  0.907121  0.120014  0.114532
#
#     out_rec  v_measure  cluster_n  count_cluster_n
# 0  0.235519   0.311028        9.0                8
# 1  0.177322   0.278597       10.0                4
# 2  0.170219   0.247831       13.0                4
# 3  0.165574   0.236309       12.0                2
# 4  0.160366   0.505519        5.0               83
# 5  0.153800   0.247168        6.0               11
# 6  0.153572   0.312470        8.0               27
# 7  0.150195   0.591525        4.0               21
# 8  0.143362   0.333175        7.0               17
# 9  0.126047   0.259387       11.0                3

# %%
df_mean = df.groupby("cluster_n")[score_cols].max()
df_mean["count_cluster_n"] = df.groupby("cluster_n")[score_cols].size()
df_mean = df_mean.sort_values(by="f1_macro", ascending=False).reset_index(drop=True)
df_mean.head(20)
# Out:
#    completeness  f1_macro  homogeneity     in_f1    out_f1  out_prec  \
# 0      0.205699  0.619789     0.794173  0.927403  0.312175  0.297915
# 1      0.258039  0.607134     0.942439  0.924986  0.289282  0.276068
# 2      0.508484  0.599656     0.886807  0.923558  0.275754  0.263158
# 3      0.175790  0.579524     0.777113  0.919714  0.239334  0.228401
# 4      0.159393  0.561693     0.787777  0.916310  0.207076  0.197617
# 5      0.320243  0.549614     0.930601  0.914003  0.185224  0.176763
# 6      0.146310  0.549038     0.782391  0.913893  0.184183  0.175770
# 7      0.309938  0.543861     0.786685  0.912905  0.174818  0.166832
# 8      0.493256  0.540985     0.784732  0.912356  0.169615  0.161867
# 9      0.166821  0.527180     0.783038  0.909720  0.144641  0.138034
#
#     out_rec  v_measure  cluster_n  count_cluster_n
# 0  0.327869   0.326762        9.0                8
# 1  0.303825   0.394251        8.0               27
# 2  0.289617   0.646356        5.0               83
# 3  0.251366   0.286721       10.0                4
# 4  0.217486   0.265139       13.0                4
# 5  0.194536   0.476508        7.0               17
# 6  0.193443   0.246519       12.0                2
# 7  0.183607   0.442663        6.0               11
# 8  0.178142   0.605755        4.0               21
# 9  0.151913   0.275045       11.0                3
