# %%
import pandas as pd

files = ["/home/philipp/projects/dad4td/reports/clustering/0002_cluster_eval_wiki.tsv", 
         "/home/philipp/projects/dad4td/reports/clustering/0003_cluster_eval_wiki.tsv"]
df = pd.concat([pd.read_csv(filename, sep="\t") for filename in files]).reset_index(drop=True)

df_mean = df.groupby("hash").mean()
df_mean = df_mean.sort_values("f1_macro")

score_cols = ['completeness',
              'f1_macro',
              'homogeneity',
              'in_f1',
              'out_f1',
              'out_prec',
              'out_rec',
              'v_measure',
             'cluster_n']
data_cols = ['Unnamed: 0',
             'contamination',
             'data_frac',
             'seed']
param_cols = [x for x in list(df.columns) if x not in score_cols]
param_cols = [x for x in param_cols if x not in data_cols]
cols = score_cols + param_cols
df
# Out:
#      Unnamed: 0  cluster_n  completeness  contamination  data_frac  f1_macro  \
# 0             0        3.0      1.000000            0.1       0.15  0.527180
# 1             1        3.0      1.000000            0.1       0.15  0.509349
# 2             2        3.0      1.000000            0.1       0.15  0.814208
# 3             3        3.0      1.000000            0.1       0.15  0.589878
# 4             4        3.0      1.000000            0.1       0.15  0.547888
# ..          ...        ...           ...            ...        ...       ...
# 715         175        6.0      0.268888            0.1       0.15  0.542136
# 716         176        6.0      0.270280            0.1       0.15  0.591028
# 717         177        6.0      0.270748            0.1       0.15  0.544437
# 718         178        6.0      0.269268            0.1       0.15  0.621514
# 719         179        6.0      0.269936            0.1       0.15  0.553065
#
#                   hash  homogeneity     in_f1  min_cluster_sizes_  \
# 0    100|1.0|cosine|60     0.000000  0.909720                60.0
# 1      5|0.6|cosine|11     0.000000  0.906315                11.0
# 2     5|0.45|cosine|60     0.000000  0.964525                60.0
# 3     5|0.45|cosine|45     0.000000  0.921691                45.0
# 4     5|0.45|cosine|30     0.000000  0.913674                30.0
# ..                 ...          ...       ...                 ...
# 715    5|0.3|cosine|30     0.879233  0.912576                30.0
# 716    5|1.0|cosine|30     0.880693  0.921911                30.0
# 717    3|0.4|cosine|30     0.882334  0.913015                30.0
# 718   10|0.5|cosine|30     0.882581  0.927732                30.0
# 719    5|0.6|cosine|30     0.883820  0.914662                30.0
#
#      mix_ratios_  n_comps_    out_f1  out_prec   out_rec  seed       time  \
# 0           1.00     100.0  0.144641  0.138034  0.151913  44.0  62.694631
# 1           0.60       5.0  0.112383  0.107249  0.118033  43.0  18.106513
# 2           0.45       5.0  0.663892  0.633565  0.697268  43.0  16.449304
# 3           0.45       5.0  0.258065  0.246276  0.271038  43.0  16.390095
# 4           0.45       5.0  0.182102  0.173784  0.191257  43.0  16.276163
# ..           ...       ...       ...       ...       ...   ...        ...
# 715         0.30       5.0  0.171696  0.163853  0.180328  43.0  14.039975
# 716         1.00       5.0  0.260146  0.248262  0.273224  43.0  22.509645
# 717         0.40       3.0  0.175858  0.167825  0.184699  43.0  14.411529
# 718         0.50      10.0  0.315297  0.300894  0.331148  43.0  18.162914
# 719         0.60       5.0  0.191467  0.182721  0.201093  43.0  18.046287
#
#     umap_metrics_  v_measure
# 0          cosine   0.000000
# 1          cosine   0.000000
# 2          cosine   0.000000
# 3          cosine   0.000000
# 4          cosine   0.000000
# ..            ...        ...
# 715        cosine   0.411830
# 716        cosine   0.413622
# 717        cosine   0.414351
# 718        cosine   0.412642
# 719        cosine   0.413561
#
# [720 rows x 19 columns]

# %%
# best f1 macro
df_mean = df.groupby("hash")[score_cols].mean()
df_mean = df_mean.reset_index()
df_mean = df_mean.sort_values(by
[score_cols].mean()
df_mean = df_mean.reset_index()
df_mean = df_mean.sort_values(by="f1_macro", ascending=True).reset_index(drop=True)
df_mean.head(20)
# Out:
#                  hash  completeness  f1_macro  homogeneity     in_f1  \
# 0     3|0.0|cosine|60      0.384853  0.479438     0.170274  0.900604
# 1     3|0.0|cosine|15      0.062540  0.482698     0.400675  0.901226
# 2     3|0.0|cosine|30      0.077748  0.491326     0.283735  0.902874
# 3     3|0.0|cosine|45      0.379076  0.503789     0.179630  0.905254
# 4     5|0.0|cosine|15      0.076885  0.504364     0.444811  0.905363
# 5     3|0.0|cosine|11      0.062486  0.506665     0.465075  0.905803
# 6     5|0.0|cosine|11      0.087416  0.511458     0.674539  0.906718
# 7   10|0.15|cosine|15      0.756250  0.525071     0.291645  0.909317
# 8   50|0.15|cosine|11      0.181900  0.527372     0.573686  0.909757
# 9    5|0.15|cosine|11      0.147682  0.527756     0.453175  0.909830
# 10    10|0.3|cosine|7      0.099259  0.528714     0.225869  0.910013
# 11   50|0.45|cosine|7      0.403481  0.529673     0.160027  0.910196
# 12    50|1.0|cosine|7      0.168199  0.531399     0.161301  0.910525
# 13   3|0.45|cosine|11      0.509135  0.532549     0.578894  0.910745
# 14   50|0.0|cosine|60      0.015398  0.534083     0.029423  0.911038
# 15    5|0.0|cosine|60      0.118496  0.534275     0.265538  0.911075
# 16   50|0.0|cosine|45      0.021611  0.534466     0.060348  0.911111
# 17   3|0.15|cosine|60      0.711138  0.534466     0.583744  0.911111
# 18  100|0.0|cosine|60      0.007530  0.534658     0.024895  0.911148
# 19  100|0.0|cosine|45      0.015196  0.534658     0.062487  0.911148
#
#       out_f1  out_prec   out_rec  v_measure  cluster_n
# 0   0.058273  0.055611  0.061202   0.078504   5.333333
# 1   0.064169  0.061238  0.067395   0.108158  23.333333
# 2   0.079778  0.076134  0.083789   0.119925   8.333333
# 3   0.102324  0.097650  0.107468   0.072912   5.666667
# 4   0.103365  0.098643  0.108561   0.131040  20.333333
# 5   0.107527  0.102615  0.112933   0.110093  44.000000
# 6   0.116198  0.110890  0.122040   0.154604  36.666667
# 7   0.140826  0.134393  0.147905   0.137065   3.666667
# 8   0.144988  0.138365  0.152277   0.271461   6.000000
# 9   0.145682  0.139027  0.153005   0.222015   7.333333
# 10  0.147416  0.140682  0.154827   0.137912   4.000000
# 11  0.149150  0.142337  0.156648   0.097539   3.333333
# 12  0.152272  0.145316  0.159927   0.101144   3.666667
# 13  0.154353  0.147302  0.162113   0.269216   5.666667
# 14  0.157128  0.149950  0.165027   0.020183   4.333333
# 15  0.157475  0.150281  0.165392   0.161379   6.333333
# 16  0.157822  0.150612  0.165756   0.031436   5.666667
# 17  0.157822  0.150612  0.165756   0.426772   4.333333
# 18  0.158169  0.150943  0.166120   0.011559   5.333333
# 19  0.158169  0.150943  0.166120   0.024341   6.666667

# %%
df_mean = df.groupby("mix_ratios_")[score_cols].mean()
df_mean = df_mean.reset_index()
df_mean = df_mean.sort_values(by="f1_macro", ascending=False).reset_index(drop=True)
df_mean.head(20)
# Out:
#    mix_ratios_  completeness  f1_macro  homogeneity     in_f1    out_f1  \
# 0         0.50      0.924720  0.633758     0.332669  0.930071  0.337446
# 1         0.40      0.847864  0.618095     0.323697  0.927079  0.309111
# 2         1.00      0.809525  0.613014     0.137594  0.926111  0.299918
# 3         0.60      0.793628  0.607241     0.229572  0.925009  0.289472
# 4         0.30      0.756597  0.598027     0.325048  0.923277  0.272777
# 5         0.45      0.710555  0.591885     0.236108  0.922078  0.261691
# 6         0.15      0.512395  0.566431     0.320908  0.917247  0.215615
# 7         0.00      0.084510  0.543433     0.289132  0.912823  0.174043
#
#    out_prec   out_rec  v_measure  cluster_n
# 0  0.322039  0.354402   0.318370   3.472222
# 1  0.294991  0.324651   0.279813   3.555556
# 2  0.286223  0.314988   0.098191   3.103175
# 3  0.276278  0.303990   0.185736   3.539683
# 4  0.260388  0.286408   0.237296   3.865079
# 5  0.249754  0.274827   0.166576   3.722222
# 6  0.205793  0.226424   0.170765   4.877778
# 7  0.166093  0.182793   0.083459  26.555556

# %%
df_mean = df.groupby("n_comps_")[score_cols].mean()
df_mean = df_mean.reset_index()
df_mean = df_mean.sort_values(by="f1_macro", ascending=False).reset_index(drop=True)
df_mean.head(20)
# Out:
#    n_comps_  completeness  f1_macro  homogeneity     in_f1    out_f1  \
# 0       5.0      0.719016  0.601596     0.276840  0.923929  0.279263
# 1      10.0      0.720076  0.598696     0.226213  0.923378  0.274014
# 2       3.0      0.622588  0.597308     0.409903  0.923131  0.271485
# 3      50.0      0.591656  0.584028     0.239216  0.920579  0.247477
# 4     100.0      0.634738  0.576443     0.072125  0.919156  0.233731
#
#    out_prec   out_rec  v_measure  cluster_n
# 0  0.266509  0.293300   0.174683   6.357143
# 1  0.261507  0.287776   0.157519   5.732143
# 2  0.259117  0.285096   0.275283   7.363095
# 3  0.236208  0.259877   0.173657   6.768519
# 4  0.223109  0.245416   0.039521   6.870370

# %%
df_mean = df.groupby("min_cluster_sizes_")[score_cols].mean()
df_mean = df_mean.reset_index()
df_mean = df_mean.sort_values(by="f1_macro", ascending=False).reset_index(drop=True)
df_mean.head(20)
# Out:
#    min_cluster_sizes_  completeness  f1_macro  homogeneity     in_f1  \
# 0                60.0      0.807974  0.628575     0.232200  0.929102
# 1                90.0      0.912493  0.624339     0.250270  0.928347
# 2                45.0      0.712582  0.606022     0.226695  0.924780
# 3                30.0      0.750473  0.602516     0.256559  0.924105
# 4               120.0      0.938787  0.589805     0.233295  0.921678
# 5                15.0      0.533622  0.568489     0.297111  0.917611
# 6                 7.0      0.294485  0.563214     0.284953  0.916603
# 7                11.0      0.516144  0.556652     0.294114  0.915348
#
#      out_f1  out_prec   out_rec  v_measure  cluster_n
# 0  0.328049  0.313088  0.344513   0.202479   3.629630
# 1  0.320330  0.305821  0.336296   0.230223   3.355556
# 2  0.287263  0.274216  0.301615   0.174365   3.966667
# 3  0.280927  0.268095  0.295050   0.192674   4.162963
# 4  0.257932  0.246156  0.270893   0.229880   3.288889
# 5  0.219366  0.209355  0.230383   0.142764   6.500000
# 6  0.209824  0.200246  0.220364   0.123639  17.700000
# 7  0.197955  0.188915  0.207905   0.126237   9.500000

# %%
min_

# %%
0.058273df_mean = df.groupby("cluster_n")[score_cols].max()
df_mean["count_cluster_n"] = df.groupby("cluster_n")[score_cols].size()
df_mean = df_mean.sort_values(by="f1_macro", ascending=False).reset_index(drop=True)
df_mean.head(20)
# Out:
#   File "<ipython-input-13-00303683d5af>", line 1
#     0.058273df_mean = df.groupby("cluster_n")[score_cols].max()
#                   ^
# SyntaxError: invalid syntax
