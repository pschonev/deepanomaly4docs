# %%
0.0582730.058273import pandas as pd

files = ["/home/philipp/projects/dad4td/reports/clustering/0001_cluster_eval_apnews.tsv"]
df = pd.concat([pd.read_csv(filename, sep="\t") for filename in files]).reset_index(drop=True)

df_mean = df.groupby("hash").mean()
df_mean = df_mean.sort_values("f1_macro")

score_cols = ['completeness',
              'f1_macro',
              'homogeneity',
              'in_f1',
              'out_f1',
              'out_prec',
              'out_rec',
              'v_measure',
             'cluster_n']
data_cols = ['Unnamed: 0',
             'contamination',
             'data_frac',
             'seed']
param_cols = [x for x in list(df.columns) if x not in score_cols]
param_cols = [x for x in param_cols if x not in data_cols]
cols = score_cols + param_cols
df
# Out:
#      Unnamed: 0  cluster_n  completeness  contamination  data_frac  f1_macro  \
# 0             0        3.0      1.000000            0.1       0.15  0.653726
# 1             1        3.0      1.000000            0.1       0.15  0.635319
# 2             2        3.0      1.000000            0.1       0.15  0.711246
# 3             3        3.0      1.000000            0.1       0.15  0.701468
# 4             4        3.0      1.000000            0.1       0.15  0.669832
# ..          ...        ...           ...            ...        ...       ...
# 175         175        7.0      0.061590            0.1       0.15  0.512225
# 176         176        6.0      0.095818            0.1       0.15  0.607709
# 177         177        7.0      0.070259            0.1       0.15  0.528331
# 178         178        4.0      0.627193            0.1       0.15  0.838367
# 179         179        6.0      0.271437            0.1       0.15  0.549038
#
#                   hash  homogeneity     in_f1  min_cluster_sizes_  \
# 0      3|0.3|cosine|30     0.000000  0.933882                30.0
# 1    10|0.4|cosine|120     0.000000  0.930368               120.0
# 2     10|0.5|cosine|60     0.000000  0.944865                60.0
# 3     10|0.5|cosine|90     0.000000  0.942998                90.0
# 4    10|0.5|cosine|120     0.000000  0.936958               120.0
# ..                 ...          ...       ...                 ...
# 175   10|1.0|cosine|30     0.254493  0.906864                30.0
# 176   10|0.6|cosine|30     0.259147  0.925096                30.0
# 177   10|0.4|cosine|30     0.280169  0.909940                30.0
# 178    3|0.5|cosine|30     0.356356  0.969138                30.0
# 179   10|0.5|cosine|30     0.858408  0.913893                30.0
#
#      mix_ratios_  n_comps_    out_f1  out_prec   out_rec  seed       time  \
# 0            0.3       3.0  0.373569  0.356504  0.392350  42.0  21.552262
# 1            0.4      10.0  0.340271  0.324727  0.357377  43.0  18.754507
# 2            0.5      10.0  0.477627  0.455809  0.501639  43.0  19.898713
# 3            0.5      10.0  0.459938  0.438928  0.483060  43.0  20.006490
# 4            0.5      10.0  0.402706  0.384310  0.422951  43.0  20.392702
# ..           ...       ...       ...       ...       ...   ...        ...
# 175          1.0      10.0  0.117586  0.112214  0.123497  43.0  25.901716
# 176          0.6      10.0  0.290323  0.277061  0.304918  42.0  20.732881
# 177          0.4      10.0  0.146722  0.140020  0.154098  43.0  17.882449
# 178          0.5       3.0  0.707596  0.675273  0.743169  42.0  15.836288
# 179          0.5      10.0  0.184183  0.175770  0.193443  43.0  19.316160
#
#     umap_metrics_  v_measure
# 0          cosine   0.000000
# 1          cosine   0.000000
# 2          cosine   0.000000
# 3          cosine   0.000000
# 4          cosine   0.000000
# ..            ...        ...
# 175        cosine   0.099178
# 176        cosine   0.139907
# 177        cosine   0.112345
# 178        cosine   0.454485
# 179        cosine   0.412452
#
# [180 rows x 19 columns]

# %%
# best f1 macro
df_mean = df.groupby("hash")[score_cols].mean()
df_mean = df_mean.reset_index()
df_mean = df_mean.sort_values(by="v_measure", ascending=False).reset_index(drop=True)
df_mean.head(20)
# Out:
#                 hash  completeness  f1_macro  homogeneity     in_f1    out_f1  \
# 0    3|0.5|cosine|30      0.548205  0.705494     0.119942  0.943767  0.467222
# 1   10|0.5|cosine|30      0.428046  0.624007     0.288144  0.928208  0.319806
# 2   10|0.6|cosine|30      0.698606  0.575690     0.086382  0.918982  0.232397
# 3   10|0.4|cosine|30      0.690086  0.555174     0.093390  0.915065  0.195283
# 4   10|1.0|cosine|30      0.687197  0.586901     0.084831  0.921144  0.252658
# 5    5|0.6|cosine|30      0.345067  0.637620     0.002471  0.930807  0.344433
# 6    3|0.5|cosine|60      0.673031  0.610202     0.001840  0.925572  0.294832
# 7    3|0.6|cosine|60      0.672706  0.619213     0.001419  0.927293  0.311134
# 8    3|0.3|cosine|30      0.672551  0.594288     0.001241  0.922533  0.266042
# 9    5|0.6|cosine|60      0.672444  0.617871     0.001125  0.927036  0.308706
# 10   5|0.3|cosine|60      0.672373  0.659286     0.001052  0.934944  0.383628
# 11   3|0.6|cosine|30      0.672276  0.608285     0.000958  0.925206  0.291363
# 12   5|0.3|cosine|30      0.672197  0.582975     0.000885  0.920373  0.245578
# 13   3|0.6|cosine|90      1.000000  0.649316     0.000000  0.933040  0.365591
# 14  3|1.0|cosine|120      1.000000  0.659286     0.000000  0.934944  0.383628
# 15   5|1.0|cosine|60      1.000000  0.609243     0.000000  0.925389  0.293097
# 16   3|1.0|cosine|30      1.000000  0.605984     0.000000  0.924767  0.287201
# 17   3|1.0|cosine|60      1.000000  0.642797     0.000000  0.931796  0.353798
# 18   3|1.0|cosine|90      1.000000  0.689580     0.000000  0.940729  0.438432
# 19  5|0.3|cosine|120      1.000000  0.643947     0.000000  0.932015  0.355879
#
#     out_prec   out_rec  v_measure  cluster_n
# 0   0.445879  0.490710   0.153424   3.666667
# 1   0.305197  0.335883   0.140208   4.666667
# 2   0.221781  0.244080   0.046636   4.000000
# 3   0.186362  0.205100   0.037448   4.333333
# 4   0.241241  0.265209   0.033059   4.333333
# 5   0.328699  0.361749   0.004067   3.666667
# 6   0.281364  0.309654   0.002855   3.333333
# 7   0.296922  0.326776   0.002298   3.333333
# 8   0.253889  0.279417   0.002049   3.333333
# 9   0.294604  0.324226   0.001884   3.000000
# 10  0.366104  0.402914   0.001776   3.333333
# 11  0.278054  0.306011   0.001636   3.333333
# 12  0.234359  0.257923   0.001525   3.333333
# 13  0.348891  0.383971   0.000000   3.000000
# 14  0.366104  0.402914   0.000000   2.666667
# 15  0.279709  0.307832   0.000000   3.000000
# 16  0.274081  0.301639   0.000000   3.000000
# 17  0.337637  0.371585   0.000000   3.000000
# 18  0.418405  0.460474   0.000000   3.000000
# 19  0.339623  0.373770   0.000000   3.000000

# %%
#worst f1 macro
df_mean = df.groupby("hash")[score_cols].mean()
df_mean = df_mean.reset_index()
df_mean = df_mean.sort_values(by="f1_macro", ascending=True).reset_index(drop=True)
df_mean.head(20)
# Out:
#                  hash  completeness  f1_macro  homogeneity     in_f1  \
# 0    10|0.4|cosine|30      0.690086  0.555174     0.093390  0.915065
# 1    10|0.6|cosine|30      0.698606  0.575690     0.086382  0.918982
# 2     5|0.3|cosine|30      0.672197  0.582975     0.000885  0.920373
# 3    10|0.3|cosine|60      1.000000  0.584701     0.000000  0.920703
# 4     5|0.5|cosine|30      1.000000  0.585468     0.000000  0.920849
# 5    10|1.0|cosine|30      0.687197  0.586901     0.084831  0.921144
# 6    10|0.3|cosine|30      1.000000  0.590261     0.000000  0.921765
# 7    10|0.3|cosine|90      1.000000  0.591412     0.000000  0.921984
# 8     3|0.3|cosine|30      0.672551  0.594288     0.001241  0.922533
# 9    10|0.5|cosine|60      1.000000  0.595438     0.000000  0.922753
# 10    5|0.5|cosine|60      1.000000  0.602724     0.000000  0.924144
# 11    3|1.0|cosine|30      1.000000  0.605984     0.000000  0.924767
# 12    5|1.0|cosine|30      1.000000  0.607134     0.000000  0.924986
# 13    3|0.6|cosine|30      0.672276  0.608285     0.000958  0.925206
# 14    3|0.3|cosine|60      1.000000  0.608476     0.000000  0.925243
# 15    5|1.0|cosine|60      1.000000  0.609243     0.000000  0.925389
# 16    3|0.5|cosine|60      0.673031  0.610202     0.001840  0.925572
# 17   10|0.4|cosine|90      1.000000  0.613845     0.000000  0.926268
# 18  10|0.3|cosine|120      1.000000  0.614037     0.000000  0.926304
# 19   3|0.3|cosine|120      1.000000  0.616337     0.000000  0.926744
#
#       out_f1  out_prec   out_rec  v_measure  cluster_n
# 0   0.195283  0.186362  0.205100   0.037448   4.333333
# 1   0.232397  0.221781  0.244080   0.046636   4.000000
# 2   0.245578  0.234359  0.257923   0.001525   3.333333
# 3   0.248699  0.237339  0.261202   0.000000   3.000000
# 4   0.250087  0.238663  0.262659   0.000000   3.000000
# 5   0.252658  0.241241  0.265209   0.033059   4.333333
# 6   0.258758  0.246938  0.271767   0.000000   2.666667
# 7   0.260839  0.248924  0.273953   0.000000   3.000000
# 8   0.266042  0.253889  0.279417   0.002049   3.333333
# 9   0.268123  0.255876  0.281603   0.000000   3.000000
# 10  0.281304  0.268454  0.295446   0.000000   3.000000
# 11  0.287201  0.274081  0.301639   0.000000   3.000000
# 12  0.289282  0.276068  0.303825   0.000000   3.000000
# 13  0.291363  0.278054  0.306011   0.001636   3.333333
# 14  0.291710  0.278385  0.306375   0.000000   3.000000
# 15  0.293097  0.279709  0.307832   0.000000   3.000000
# 16  0.294832  0.281364  0.309654   0.002855   3.333333
# 17  0.301422  0.287653  0.316576   0.000000   3.000000
# 18  0.301769  0.287984  0.316940   0.000000   3.000000
# 19  0.305931  0.291956  0.321311   0.000000   3.000000

# %%
df_mean = df.groupby("mix_ratios_")[score_cols].mean()
df_mean = df_mean.reset_index()
df_mean = df_mean.sort_values(by="f1_macro", ascending=False).reset_index(drop=True)
df_mean.head(20)
# Out:
#    mix_ratios_  completeness  f1_macro  homogeneity     in_f1    out_f1  \
# 0          0.5      0.887440  0.631277     0.034161  0.929596  0.332958
# 1          1.0      0.973933  0.630406     0.007069  0.929432  0.331380
# 2          0.4      0.974174  0.627453     0.007782  0.928894  0.326012
# 3          0.6      0.838425  0.623703     0.007696  0.928150  0.319257
# 4          0.3      0.918093  0.614308     0.000265  0.926356  0.302260
#
#    out_prec   out_rec  v_measure  cluster_n
# 0  0.317748  0.349696   0.024707   3.222222
# 1  0.316253  0.348027   0.002755   3.083333
# 2  0.311394  0.342077   0.003121   3.111111
# 3  0.304673  0.335307   0.004710   3.138889
# 4  0.288453  0.317456   0.000446   3.055556

# %%
df_mean = df.groupby("n_comps_")[score_cols].mean()
df_mean = df_mean.reset_index()
df_mean = df_mean.sort_values(by="f1_macro", ascending=False).reset_index(drop=True)
df_mean.head(20)
# Out:
#    n_comps_  completeness  f1_macro  homogeneity     in_f1    out_f1  \
# 0       3.0      0.911938  0.639998     0.006270  0.931271  0.348725
# 1       5.0      0.918104  0.627215     0.000277  0.928827  0.325602
# 2      10.0      0.925197  0.609075     0.027637  0.925358  0.292792
#
#    out_prec   out_rec  v_measure  cluster_n
# 0  0.332911  0.366120   0.008113   3.083333
# 1  0.310777  0.341913   0.000463   3.033333
# 2  0.279424  0.307505   0.012868   3.250000

# %%
df_mean = df.groupby("min_cluster_sizes_")[score_cols].mean()
df_mean = df_mean.reset_index()
df_mean = df_mean.sort_values(by="f1_macro", ascending=False).reset_index(drop=True)
df_mean.head(20)
# Out:
#    min_cluster_sizes_  completeness  f1_macro  homogeneity     in_f1  \
# 0                90.0      1.000000  0.636955     0.000000  0.930680
# 1               120.0      1.000000  0.636380     0.000000  0.930571
# 2                60.0      0.912704  0.620002     0.000362  0.927466
# 3                30.0      0.760949  0.608380     0.045216  0.925226
#
#      out_f1  out_prec   out_rec  v_measure  cluster_n
# 0  0.343230  0.327552  0.360486   0.000000   2.977778
# 1  0.342190  0.326559  0.359393   0.000000   2.955556
# 2  0.312538  0.298481  0.327990   0.000588   3.066667
# 3  0.291535  0.278225  0.306181   0.028004   3.488889

# %%
df_mean = df.groupby("cluster_n")[score_cols].mean()
df_mean["count_cluster_n"] = df.groupby("cluster_n")[score_cols].size()
df_mean = df_mean.sort_values(by="f1_macro", ascending=False).reset_index(drop=True)
df_mean.head(20)
# Out:
#    completeness  f1_macro  homogeneity     in_f1    out_f1  out_prec  \
# 0      1.000000  0.696061     0.000000  0.941966  0.450156  0.429593
# 1      0.012702  0.675008     0.006023  0.937946  0.412071  0.393247
# 2      0.072959  0.628469     0.035709  0.929060  0.327878  0.312901
# 3      1.000000  0.624601     0.000000  0.928328  0.320873  0.306280
# 4      0.183628  0.578374     0.558778  0.919495  0.237253  0.226415
# 5      0.065925  0.520278     0.267331  0.908402  0.132154  0.126117
#
#     out_rec  v_measure  cluster_n  count_cluster_n
# 0  0.472787   0.000000        2.0                5
# 1  0.432787   0.008171        5.0                1
# 2  0.344362   0.046777        4.0               11
# 3  0.336928   0.000000        3.0              159
# 4  0.249180   0.276180        6.0                2
# 5  0.138798   0.105762        7.0                2

# %%
df_mean = df.groupby("cluster_n")[score_cols].max()
df_mean["count_cluster_n"] = df.groupby("cluster_n")[score_cols].size()
df_mean = df_mean.sort_values(by="f1_macro", ascending=False).reset_index(drop=True)
df_mean.head(20)
# Out:
#    completeness  f1_macro  homogeneity     in_f1    out_f1  out_prec  \
# 0      0.627193  0.838367     0.356356  0.969138  0.707596  0.675273
# 1      1.000000  0.815359     0.000000  0.964745  0.665973  0.635551
# 2      1.000000  0.750360     0.000000  0.952334  0.548387  0.523337
# 3      0.012702  0.675008     0.006023  0.937946  0.412071  0.393247
# 4      0.271437  0.607709     0.858408  0.925096  0.290323  0.277061
# 5      0.070259  0.528331     0.280169  0.909940  0.146722  0.140020
#
#     out_rec  v_measure  cluster_n  count_cluster_n
# 0  0.743169   0.454485        4.0               11
# 1  0.699454   0.000000        3.0              159
# 2  0.575956   0.000000        2.0                5
# 3  0.432787   0.008171        5.0                1
# 4  0.304918   0.412452        6.0                2
# 5  0.154098   0.112345        7.0                2
